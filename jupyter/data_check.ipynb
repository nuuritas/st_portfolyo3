# %%
import pandas as pd
import warnings; warnings.simplefilter('ignore')
import numpy as np
import json
import requests
import concurrent.futures
from tqdm import tqdm

# %%
gunluk_ozet = pd.read_parquet("../data/parquet/gunluk_ozet.parquet")
haftalık_ozet = pd.read_parquet("../data/parquet/haftalık_ozet.parquet")
port_all = pd.read_parquet("../data/parquet/port_all.parquet")

# %%
investment_df = pd.read_parquet("../data/midas_raw/midas_df.parquet")
investment_df
# Out:
#           date   order_type ticker buy_sell       status currency  quantity  \
# 0   2023-10-02   Limit Emri  KLSER    Satış  Gerçekleşti      TRY      28.0
# 1   2023-10-02   Limit Emri  ISCTR    Satış  Gerçekleşti      TRY     600.0
# 2   2023-10-02   Limit Emri  YKBNK     Alış  Gerçekleşti      TRY     250.0
# 3   2023-10-02   Limit Emri  AKBNK     Alış  Gerçekleşti      TRY     125.0
# 4   2023-10-02   Limit Emri  MGROS    Satış  Gerçekleşti      TRY      19.0
# ..         ...          ...    ...      ...          ...      ...       ...
# 277 2023-09-29  Piyasa Emri  ADGYO     Alış  Gerçekleşti      TRY      42.0
# 278 2023-09-29  Piyasa Emri  SDTTR    Satış  Gerçekleşti      TRY      16.0
# 279 2023-09-29  Piyasa Emri  REEDR     Alış  Gerçekleşti      TRY     330.0
# 280 2023-09-29  Piyasa Emri  TURSG    Satış  Gerçekleşti      TRY      75.0
# 281 2023-09-29  Piyasa Emri  REEDR     Alış  Gerçekleşti      TRY     168.0
#
#     order_amount  realized_q   price  trans_fee  trans_amount  adj_q
# 0              -        28.0   96.35       0.85       2697.80  -28.0
# 1              -       600.0   25.90       4.90      15540.00 -600.0
# 2              -       250.0   18.48       1.46       4620.00  250.0
# 3              -       125.0   33.48       1.32       4185.00  125.0
# 4              -        19.0  368.30       2.20       6997.70  -19.0
# ..           ...         ...     ...        ...           ...    ...
# 277            -        42.0   27.86       0.37       1169.92   42.0
# 278            -        16.0  375.30       1.89       6004.80  -16.0
# 279            -       330.0   17.74       1.84       5854.20  330.0
# 280            -        75.0   38.20       0.90       2865.00  -75.0
# 281            -       168.0   17.75       0.94       2982.00  168.0
#
# [282 rows x 13 columns]
