# %%
import pandas as pd
import warnings; warnings.simplefilter('ignore')
import numpy as np
import json
import requests
import concurrent.futures
from tqdm import tqdm

# %%
gunluk_ozet = pd.read_parquet("../data/parquet/gunluk_ozet.parquet")
haftalık_ozet = pd.read_parquet("../data/parquet/haftalık_ozet.parquet")
port_all = pd.read_parquet("../data/parquet/port_all.parquet")

# %%
investment_df = pd.read_parquet("../data/midas_raw/midas_df.parquet")
investment_df
# Out:
#           date  order_type ticker buy_sell       status currency  quantity  \
# 0   2023-10-02  Limit Emri  KLSER    Satış  Gerçekleşti      TRY      28.0
# 1   2023-10-02  Limit Emri  ISCTR    Satış  Gerçekleşti      TRY     600.0
# 2   2023-10-02  Limit Emri  YKBNK     Alış  Gerçekleşti      TRY     250.0
# 3   2023-10-02  Limit Emri  AKBNK     Alış  Gerçekleşti      TRY     125.0
# 4   2023-10-02  Limit Emri  MGROS    Satış  Gerçekleşti      TRY      19.0
# ..         ...         ...    ...      ...          ...      ...       ...
# 298 2023-10-06        None  TURSG     Alış         None     None       NaN
# 299 2023-10-09        None  ASUZU    Satış         None     None       NaN
# 300 2023-10-09        None  MSGYO    Satış         None     None       NaN
# 301 2023-10-09        None  AVGYO    Satış         None     None       NaN
# 302 2023-10-09        None  HEKTS     Alış         None     None       NaN
#
#     order_amount  realized_q   price  trans_fee  trans_amount  adj_q
# 0              -        28.0   96.35       0.85        2697.8  -28.0
# 1              -       600.0   25.90       4.90       15540.0 -600.0
# 2              -       250.0   18.48       1.46        4620.0  250.0
# 3              -       125.0   33.48       1.32        4185.0  125.0
# 4              -        19.0  368.30       2.20        6997.7  -19.0
# ..           ...         ...     ...        ...           ...    ...
# 298         None        51.0   42.66        NaN           NaN    NaN
# 299         None         8.0  258.20        NaN           NaN    NaN
# 300         None       140.0   10.27        NaN           NaN    NaN
# 301         None       350.0    8.07        NaN           NaN    NaN
# 302         None       250.0   24.68        NaN           NaN    NaN
#
# [303 rows x 13 columns]
